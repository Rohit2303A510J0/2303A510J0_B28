# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohit2303A510J0/2303A510J0_B28/blob/main/ASSIGNMENT_4/assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Question - 1

# %%
import pandas as pd

df = pd.read_csv("course_feedback.csv")
df
# Out:
#     User_ID              Course_Name  Rating  \
# 0    user_1          Cloud Computing     NaN
# 1    user_2  Python for Data Science     4.0
# 2    user_3  Python for Data Science     5.0
# 3    user_4          Web Development     1.0
# 4    user_5          Cloud Computing     2.0
# 5    user_6         Machine Learning     4.0
# 6    user_7  Python for Data Science     1.0
# 7    user_8         Machine Learning     2.0
# 8    user_9          Cloud Computing     5.0
# 9   user_10  Python for Data Science     2.0
# 10  user_11  Python for Data Science     NaN
# 11  user_12         Machine Learning     4.0
# 12  user_13  Python for Data Science     2.0
# 13  user_14         Machine Learning     2.0
# 14  user_15         Machine Learning     2.0
# 15  user_16         Machine Learning     4.0
# 16  user_17         Machine Learning     4.0
# 17  user_18         Machine Learning     NaN
# 18  user_19          Web Development     NaN
# 19  user_20         Machine Learning     NaN
# ...

# %%
df_cleaned = df.dropna(subset=["Rating"])
df_cleaned
# Out:
#     User_ID              Course_Name  Rating  \
# 1    user_2  Python for Data Science     4.0
# 2    user_3  Python for Data Science     5.0
# 3    user_4          Web Development     1.0
# 4    user_5          Cloud Computing     2.0
# 5    user_6         Machine Learning     4.0
# 6    user_7  Python for Data Science     1.0
# 7    user_8         Machine Learning     2.0
# 8    user_9          Cloud Computing     5.0
# 9   user_10  Python for Data Science     2.0
# 11  user_12         Machine Learning     4.0
# 12  user_13  Python for Data Science     2.0
# 13  user_14         Machine Learning     2.0
# 14  user_15         Machine Learning     2.0
# 15  user_16         Machine Learning     4.0
# 16  user_17         Machine Learning     4.0
# 20  user_21          Cloud Computing     3.0
# 21  user_22          Web Development     5.0
# 23  user_24  Python for Data Science     5.0
# 24  user_25  Python for Data Science     2.0
# 25  user_26          Cloud Computing     5.0
# ...

# %%
filtered_df = df_cleaned[
    (df_cleaned["Course_Name"] == "Python for Data Science") & (df_cleaned["Rating"] >= 4)
][["User_ID", "Feedback"]]
filtered_df
# Out:
#     User_ID                                 Feedback
# 1    user_2               I learned a lot from this.
# 2    user_3  Well structured and clear explanations.
# 23  user_24       Good introduction but needs depth.

# %% [markdown]
# #Question - 2

# %%
import pandas as pd

df = pd.read_csv("air_quality.csv")
df
# Out:
#      Location  PM2.5   PM10   NO2   SO2        Date
# 0     Kolkata  135.0  156.0   NaN   NaN  2025-08-29
# 1   Bangalore    NaN  167.0  72.0   NaN  2025-08-28
# 2   Bangalore    NaN    NaN   NaN  78.0  2025-08-27
# 3   Bangalore    NaN    NaN   NaN   NaN  2025-08-26
# 4     Kolkata    NaN  144.0   NaN   NaN  2025-08-25
# 5     Kolkata    NaN  228.0   NaN   NaN  2025-08-24
# 6       Delhi    NaN    NaN  43.0   NaN  2025-08-23
# 7     Kolkata    NaN  232.0  64.0  40.0  2025-08-22
# 8       Delhi  132.0    NaN   NaN  66.0  2025-08-21
# 9      Mumbai  158.0  248.0  62.0  34.0  2025-08-20
# 10      Delhi   89.0    NaN   NaN   NaN  2025-08-19
# 11  Bangalore    NaN  116.0   NaN  45.0  2025-08-18
# 12  Bangalore   93.0  133.0   NaN  50.0  2025-08-17
# 13  Bangalore   67.0  154.0   NaN   NaN  2025-08-16
# 14      Delhi    NaN    NaN  48.0   NaN  2025-08-15
# 15      Delhi   76.0    NaN   NaN  41.0  2025-08-14
# 16     Mumbai  124.0  159.0  93.0   NaN  2025-08-13
# ...

# %%
df_cleaned = df.ffill()
df_cleaned
# Out:
#      Location  PM2.5   PM10   NO2   SO2        Date
# 0     Kolkata  135.0  156.0   NaN   NaN  2025-08-29
# 1   Bangalore  135.0  167.0  72.0   NaN  2025-08-28
# 2   Bangalore  135.0  167.0  72.0  78.0  2025-08-27
# 3   Bangalore  135.0  167.0  72.0  78.0  2025-08-26
# 4     Kolkata  135.0  144.0  72.0  78.0  2025-08-25
# 5     Kolkata  135.0  228.0  72.0  78.0  2025-08-24
# 6       Delhi  135.0  228.0  43.0  78.0  2025-08-23
# 7     Kolkata  135.0  232.0  64.0  40.0  2025-08-22
# 8       Delhi  132.0  232.0  64.0  66.0  2025-08-21
# 9      Mumbai  158.0  248.0  62.0  34.0  2025-08-20
# 10      Delhi   89.0  248.0  62.0  34.0  2025-08-19
# 11  Bangalore   89.0  116.0  62.0  45.0  2025-08-18
# 12  Bangalore   93.0  133.0  62.0  50.0  2025-08-17
# 13  Bangalore   67.0  154.0  62.0  50.0  2025-08-16
# 14      Delhi   67.0  154.0  48.0  50.0  2025-08-15
# 15      Delhi   76.0  154.0  48.0  41.0  2025-08-14
# 16     Mumbai  124.0  159.0  93.0  41.0  2025-08-13
# ...

# %%
polluted_days = df_cleaned[(df_cleaned["PM2.5"] > 150) & (df_cleaned["NO2"] > 80)]
polluted_days
# Out:
#    Location  PM2.5   PM10   NO2   SO2        Date
# 19  Kolkata  186.0  139.0  93.0  59.0  2025-08-10
# 20    Delhi  186.0  200.0  93.0  27.0  2025-08-09
# 21  Kolkata  186.0  250.0  93.0  28.0  2025-08-08
# 22  Kolkata  186.0  250.0  93.0  58.0  2025-08-07
